# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(os.path.abspath("/Users/I534731/Documents/GitHub/prava-backend"))

import pandas as pd
from baml_py import ClientRegistry
from app.utility.logger_local import get_logger

from app.utility.parse_csv_file import parse_csv_file

# %%
# Read the CSV file into a DataFrame
GLOBAL_LOGGER = get_logger()

BASE_DIR = os.path.dirname('/Users/I534731/Documents/GitHub/prava-backend/app/data/')
for file in os.listdir(BASE_DIR):
    if ".csv" in file:
        data = await parse_csv_file(
            filename=file, file=BASE_DIR + '/' + file, logger=GLOBAL_LOGGER
        )

# %%
data[3]
# Out:
# {'duration': '00:58:10',
#  'distance': 9.68,
#  'activityType': 'Laufen',
#  'calories': '679',
#  'ascent': '24',
#  'avgPace': '5:51',
#  'maxHeartRate': 161,
#  'avgHeartRate': 148,
#  'timeFinished': '00:56:34',
#  'waypoints': [],
#  'minHeartRate': 0,
#  'fileName': 'activity_2024-11-14.csv'}

# %%
print(os.environ.get("OPENAI_API_KEY"))
# Out:
# None

# %%
cr = ClientRegistry()
os.environ.get("OPENAI_API_KEY")print(OPENAI_API_KEY)
cr.add_llm_client(
        name="CustomGPT4o",
        provider="openai",
        options={"model": "gpt-4o", "api_key": OPENAI_API_KEY},
    )
cr.set_primary("CustomGPT4o")
# Out:
# Bearer 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

# %%
import app.baml_client as client


await client.b.MarathonTime(data_dict)
# Out:
# [2024-11-27T19:58:05Z WARN  baml_events] Function MarathonTime:
#     Client: openai/gpt-4o (<unknown>) - 359ms
#     ---PROMPT---
#     [chat] system: You are a running coach. The person you want to coach has the goal to complete a marathon.
#     Based on his training data, you want to set the pace and target time for him.
#     Training data:
#
#     [{
#         "activity_type": "Laufen",
#         "date": "2024-11-24 09:59:33",
#         "favorite": false,
#         "title": "Karlsruhe Laufen",
#         "distance": 15.5,
#         "calories": "280",
#         "total_time": "01:36:04",
#         "avg_heart_rate": 142,
#         "max_heart_rate": 160,
#         "aerober_training_effect": 1.0,
#         "avg_cadence": 165,
#         "max_cadence": 176,
#         "avg_pace": "6:12",
#         "max_pace": "5:18",
#         "elevation_gain": "20",
#         "descent": "17",
#         "avg_stride_length": 0.98,
#         "tse": 0.0,
#         "decompression": "Nein",
# ...
